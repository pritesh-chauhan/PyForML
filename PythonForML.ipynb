# %% [markdown]
# <a href="https://colab.research.google.com/github/pritesh-chauhan/PyForML/blob/main/PythonForML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = 'mississippi'

# TODO:
from collections import Counter
freq = Counter(s)
top_2 = freq.most_common(2)

print(freq)
print(top_2)
# Out:
# Counter({'i': 4, 's': 4, 'p': 2, 'm': 1})
# [('i', 4), ('s', 4)]
